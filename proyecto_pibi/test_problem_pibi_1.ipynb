# %%
# load packages
import torch
import torch.nn as nn
import numpy as np
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.font_manager import FontProperties
import os
from datetime import datetime
from sklearn.datasets import make_spd_matrix
from torch.utils.data import random_split, DataLoader
from scipy.stats import qmc
import time

# %%
def u_analytic(x, y):
    return np.sin(x) * np.sinh(y)

# %%
def integration_points(n_int):
    points = torch.linspace(0, 4, n_int+1)[:-1]
    points += torch.rand(points.shape) * (1 / n_int) + np.random.rand() * 0.05 # random shift

    # points on square
    epsilon =  0.3 # changeable: set the boundary an espilon away from the Omega boundary
    side = 2 + 2*epsilon
    middle = torch.tensor((0,0)).view(1,2)
    points = torch.remainder(points, 4) # transform points to [0,4]
    v1 = torch.tensor((0, side))[None,]
    v2 = torch.tensor((side, 0))[None,]
    v3 = torch.tensor((0, -side))[None,]
    v4 = torch.tensor((-side, 0))[None,]
    points = points.view(-1,1)
    x_int = (middle - 0.5 * (v1 + v2) + torch.clamp(points,0,1) * v1 + torch.clamp(points-1,0,1) * v2 + torch.clamp(points-2,0,1) * v3 + torch.clamp(points-3,0,1) * v4).requires_grad_(True)

    return x_int

# %%
# outer normal directional derivative on boundary of Omega (as a circle)
def outer_normal(x):

    middle = torch.tensor((0,0)).view(1,2)
    max_indices = torch.argmax(torch.abs(x - middle), dim=-1, keepdim=False)
    normals = torch.zeros_like(x)
    sign = torch.sign(x)
    temp_range = torch.arange(x.size(0))
    normals[temp_range, max_indices] = sign[temp_range, max_indices]

    return normals

# %%
# fundamental solution of Laplace equation in 2D
def fundamental_solution(x, y, L=None):
    diff = x - y
    if L is None:
        L = torch.tensor(4 * 2 / y.shape[0], dtype=x.dtype, device=x.device)

    Phi_analytic = -L / (2 * torch.pi) * (torch.log(L / 2) - 1)    
    distance = torch.norm(x - y, p=2, dim=1).view(-1,1)
    Phi_0 = -1/(2*torch.pi) * torch.log(distance)

    return Phi_0


# gradient of fundamental solution with respect to y
# grad Phi_0(x,y) = 1/(2π) * (x - y)/||x - y||²
def gradient_fundamental(x, y):
    diff = x - y
    distance = torch.norm(x - y, p=2, dim=1).view(-1,1)
    grad_analytic = torch.full_like(diff, -0.5)
    grad_Phi_0 = (1/(2*torch.pi)) * ((x - y) / distance**2)
    
    return grad_Phi_0

# %%
# fully-connected neural network setup with PyTorch
class FCNN(nn.Module):
    def __init__(self, N_input, N_output, N_hidden, N_layers, n_int):

        super().__init__()
        activation = nn.Tanh
        self.n_int = n_int

        # input / start layer
        self.fc_start = nn.Sequential(*[
                                nn.Linear(N_input, N_hidden),
                                activation()
                                ])
        # hidden layers
        self.fc_hidden = nn.Sequential(*[
                                nn.Sequential(*[
                                    nn.Linear(N_hidden, N_hidden),
                                    activation()
                                    ])
                                for _ in range(N_layers-1) # -1 since first layer already defined before for-loop
                                ])
        # output / end layer
        self.fc_end = nn.Linear(N_hidden, N_output)

    #------------------------------
    # forward pass through network
    def forward(self, x):
        # map x to [-1,1]
        epsilon =  0.3
        x_scaled = 2*(x - torch.tensor([-1-epsilon, -1-epsilon]))/(torch.tensor([1+epsilon, 1+epsilon]) - torch.tensor([-1-epsilon, -1-epsilon])) - 1
        #x_scaled = 2*(x - torch.tensor([x_min, y_min]))/(torch.tensor([x_max, y_max]) - torch.tensor([x_min, y_min])) - 1
        # forward pass
        x_scaled = self.fc_start(x_scaled)  # input layer
        x_scaled = self.fc_hidden(x_scaled) # hidden layer(s)
        u = self.fc_end(x_scaled)    # output layer
        return u

    #------------------------------
    # calculating the potential integrals
    def resample(self):
        # sampling new collocation and integration points
        self.x_int = integration_points(self.n_int)
        # calculating the potential
        self.vmapped_potential_inside = torch.vmap(self.calc_potentials_inside, randomness='same')

    #------------------------------
    # calculating the single and double layer potentials for x being an inside Omega point
    def calc_potentials_inside(self, x):

        epsilon =  0.3
        side = 2 + 2*epsilon

        y = self.x_int
        normal_y = outer_normal(y)
        h_y = self(y) # boundary density, performs forward pass through  neural network with the input y

 

        G =  fundamental_solution(x, y)
         
        grad_ones = torch.ones_like(h_y)
        dh_dy = torch.autograd.grad(h_y, y, grad_outputs=grad_ones, create_graph=True)[0]
        dh_dn = torch.sum(dh_dy * normal_y, dim=1).view(-1, 1)
        single_layer = 4*side*torch.mean(G * dh_dn)
        ################
        # double_layer
        dG_dy =  gradient_fundamental(x, y)
        dG_dn = torch.sum(dG_dy * normal_y, dim=1).view(-1, 1)
        double_layer = 4*side*torch.mean(dG_dn * h_y)


        return single_layer.squeeze(), double_layer.squeeze()

    #------------------------------
    def predict_u_inside(self, x):
        y = self.x_int
        single_layer, double_layer = self.vmapped_potential_inside(x)
        u_int_data = (single_layer.squeeze() - double_layer.squeeze()).view(-1, 1)

        return u_int_data

# %%
def initialise_pibi(lr, n_int):

    # define number of neurons in each layer type
    N_input  = 2
    N_output = 1
    N_hidden = 100 # changeable, use 2**n for efficient memory usage and computation
    N_layers = 3 # number of hidden layers

    # define a neural network to train
    pibi = FCNN(N_input, N_output, N_hidden, N_layers, n_int)
    
    # optimizer
    optimiser = torch.optim.Adam(pibi.parameters(), lr=lr)

    # loss function
    mse_loss = torch.nn.MSELoss() # Mean squared error
    
    return pibi, optimiser, mse_loss

# %%
# Número de muestras a generar (para malla regular y para LHS)
n_samples = 300 # number of samples
n_int = 300 # number of integration points

# Crear malla regular en el dominio [0,1]x[0,1]
x = np.linspace(-1, 1, n_samples)
y = np.linspace(-1, 1, n_samples)
X_grid, Y_grid = np.meshgrid(x, y)

# Evaluar solución analítica sobre la malla regular
U_grid = u_analytic(X_grid, Y_grid)

# Aplanar y combinar en una matriz (x, y, u) para la malla regular
num_points = n_samples ** 2
XU_grid = np.column_stack((
    X_grid.reshape(num_points),
    Y_grid.reshape(num_points),
    U_grid.reshape(num_points)
))

# Generar muestras usando Latin Hypercube Sampling (LHS)
lhs_sampler = qmc.LatinHypercube(d=2)
lhs_samples = lhs_sampler.random(n=n_samples)

# Escalar las muestras al dominio [0,1]x[0,1]
domain_bounds_lower = [-1, -1]
domain_bounds_upper = [1, 1]
lhs_scaled = qmc.scale(lhs_samples, domain_bounds_lower, domain_bounds_upper)

# Evaluar solución analítica en las muestras LHS
X_lhs, Y_lhs = lhs_scaled[:, 0], lhs_scaled[:, 1]
U_lhs = u_analytic(X_lhs, Y_lhs)

# Combinar en una matriz (x, y, u) para las muestras LHS
XU_lhs_interior = np.column_stack((X_lhs, Y_lhs, U_lhs))

# generar puntos de integración
x_int = integration_points(n_int)

# %%
# Supón que u_analytic está definida y n_samples también
# u_analytic = lambda x, y: alguna expresión analítica
n_samples = 200  # por ejemplo

# Número total de muestras en la frontera
n_side = n_samples // 4
lhs_1d = qmc.LatinHypercube(d=1).random(n=n_side)
lhs_1d = 2 * lhs_1d - 1  # escalar a [-1, 1]

# Lados del cuadrado
bottom = np.column_stack((lhs_1d[:, 0], -np.ones(n_side)))
top    = np.column_stack((lhs_1d[:, 0],  np.ones(n_side)))
left   = np.column_stack((-np.ones(n_side), lhs_1d[:, 0]))
right  = np.column_stack(( np.ones(n_side), lhs_1d[:, 0]))

# Unir todos los puntos de frontera
boundary_points = np.vstack((bottom, top, left, right))

# Evaluar la solución analítica
X_lhs, Y_lhs = boundary_points[:, 0], boundary_points[:, 1]
U_lhs = u_analytic(X_lhs, Y_lhs)

# Graficar con color de acuerdo a u
plt.figure(figsize=(5, 5))
sc = plt.scatter(X_lhs, Y_lhs, c=U_lhs, cmap='magma', s=20)
plt.colorbar(sc, label='$u(x, y)$')  # barra de colores
plt.xlim([-1.1, 1.1])
plt.ylim([-1.1, 1.1])
plt.gca().set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Puntos de evaluación')
plt.grid(True)
# Guardar la figura
plt.savefig('boundary_points.svg')
plt.show()

# %%
data_ = torch.tensor(XU_grid, dtype=torch.float64)
plt.figure(figsize=(4, 4))
plt.imshow(U_grid, extent=(-1, 1, -1, 1), origin='lower', cmap="magma")
plt.title('Solución analítica')
plt.colorbar()
plt.savefig('solucion_analitica.svg')
plt.show()

# %%
# plot outer normal and x_int
figure, ax = plt.subplots(figsize=(4, 4))
plt.scatter(x_int[:, 0].detach().numpy(), x_int[:, 1].detach().numpy())
plt.scatter(x_int[5, 0].detach().numpy(), x_int[5, 1].detach().numpy())
plt.show()
#plt.quiver(x_int[:, 0].detach().numpy(), x_int[:, 1].detach().numpy(), outer_normal(x_int)[:, 0].detach().numpy(), outer_normal(x_int)[:, 1].detach().numpy())

# %%
def train_pibi(iterations, pibi, optimiser, mse_loss, data, data_n, n_samples, n_int, time_now, show_plots):

    # store loss values
    loss_values = []
 
    for epoch in range(iterations):

        # Clear gradients before forward and backward pass for each batch to avoid accumulation of gradients
        optimiser.zero_grad()

        # compute data loss
        pibi.resample()
        u_int_data = pibi.predict_u_inside(data[:,0:2])
        #source_data = torch.zeros_like(u_int_data)
        source_data = (32*((1 - data[:,1])*data[:,1] + (1 - data[:,0])*data[:,0]))* fundamental_solution(data[:,0:2], torch.ones_like(data[:,0:2])).view(-1,1)
        u_int_data = u_int_data +  source_data
        loss = mse_loss(u_int_data, data[:,-1].view(-1,1))
        loss_values.append(loss.item())

        # backpropagate loss, take optimiser step
        loss.backward()
        optimiser.step()
        print('Epoch:', epoch, 'Loss:', loss.item())

    return pibi, loss_values

# %%
show_plots = True

# take samples
time_now = datetime.now().strftime("%Y%m%d_%H%M")
data = torch.tensor(XU_lhs, dtype=torch.float64)
data_ = torch.tensor(XU_grid, dtype=torch.float64)

# # pibi initialisation
lr = 0.001 # learning rate
pibi, optimiser, mse_loss = initialise_pibi(lr, n_int)
    
# # train pibi-net
# iterations = 1_001
# pibi, loss_values = train_pibi(iterations, pibi, optimiser, mse_loss, data, 00, n_samples, n_int, time_now, show_plots)

# %%
def train_pibi_lbfgs(pibi, mse_loss, data, max_iter=100):
    print("\nStarting L-BFGS refinement...")

    def closure():
        optimizer_lbfgs.zero_grad()
        pibi.resample()  # en caso de que resamplee los puntos en cada forward
        u_int_data = pibi.predict_u_inside(data[:, :2])
        loss = mse_loss(u_int_data, data[:, -1].view(-1, 1))
        loss.backward()
        return loss

    optimizer_lbfgs = torch.optim.LBFGS(
        pibi.parameters(),
        lr=1,
        max_iter=max_iter,
        history_size=100,
        line_search_fn="strong_wolfe",
        tolerance_grad=1e-7,
        tolerance_change=1.0 * np.finfo(float).eps
    )

    loss_values_lbfgs = []

    for i in range(max_iter):
        loss = optimizer_lbfgs.step(closure)
        loss_values_lbfgs.append(loss.item())
        print(f"[L-BFGS] Iter {i} | Loss: {loss.item():.6e}")

    return pibi, loss_values_lbfgs

# %%
from datetime import datetime

show_plots = True
time_now = datetime.now().strftime("%Y%m%d_%H%M")

# Cargar datos
data = torch.tensor(XU_lhs, dtype=torch.float64)

# Inicialización de PIBI
lr = 0.001
#pibi, optimiser, mse_loss = initialise_pibi(lr, n_int)

# Primera fase: optimizador tipo Adam
iterations = 301
#pibi, loss_values_adam = train_pibi(iterations, pibi, optimiser, mse_loss, data, 00, n_samples, n_int, time_now, show_plots)

# Segunda fase: refinamiento con L-BFGS
pibi, loss_values_lbfgs = train_pibi_lbfgs(pibi, mse_loss, data, max_iter=iterations)
# Out:
# Starting L-BFGS refinement...
# [L-BFGS] Iter 0 | Loss: 3.333166e-01
# [L-BFGS] Iter 1 | Loss: 3.328075e-03
# [L-BFGS] Iter 2 | Loss: 3.157934e-03
# [L-BFGS] Iter 3 | Loss: 3.200169e-03
# [L-BFGS] Iter 4 | Loss: 1.796408e-03
# [L-BFGS] Iter 5 | Loss: 1.793013e-03
# [L-BFGS] Iter 6 | Loss: 1.794527e-03
# [L-BFGS] Iter 7 | Loss: 1.781729e-03
# [L-BFGS] Iter 8 | Loss: 1.788504e-03
# [L-BFGS] Iter 9 | Loss: 1.802309e-03
# [L-BFGS] Iter 10 | Loss: 1.771631e-03
# [L-BFGS] Iter 11 | Loss: 1.121003e-03
# [L-BFGS] Iter 12 | Loss: 9.612974e-04
# [L-BFGS] Iter 13 | Loss: 9.578137e-04
# [L-BFGS] Iter 14 | Loss: 8.928100e-04
# [L-BFGS] Iter 15 | Loss: 8.551362e-04
# [L-BFGS] Iter 16 | Loss: 9.436069e-04
# [L-BFGS] Iter 17 | Loss: 9.351969e-04
# [L-BFGS] Iter 18 | Loss: 4.026490e-04
# [L-BFGS] Iter 19 | Loss: 4.053425e-04
# [L-BFGS] Iter 20 | Loss: 4.465313e-04
# [L-BFGS] Iter 21 | Loss: 3.801295e-04
# [L-BFGS] Iter 22 | Loss: 2.737498e-04
# [L-BFGS] Iter 23 | Loss: 2.869135e-04
# [L-BFGS] Iter 24 | Loss: 3.283392e-04
# [L-BFGS] Iter 25 | Loss: 2.839562e-04
# [L-BFGS] Iter 26 | Loss: 2.708306e-04
# [L-BFGS] Iter 27 | Loss: 2.578240e-04
# [L-BFGS] Iter 28 | Loss: 2.644336e-04
# [L-BFGS] Iter 29 | Loss: 2.399312e-04
# [L-BFGS] Iter 30 | Loss: 2.600120e-04
# [L-BFGS] Iter 31 | Loss: 2.768752e-04
# [L-BFGS] Iter 32 | Loss: 2.514652e-04
# [L-BFGS] Iter 33 | Loss: 2.560785e-04
# [L-BFGS] Iter 34 | Loss: 2.447169e-04
# [L-BFGS] Iter 35 | Loss: 2.376768e-04
# [L-BFGS] Iter 36 | Loss: 2.814724e-04
# [L-BFGS] Iter 37 | Loss: 2.252976e-04
# [L-BFGS] Iter 38 | Loss: 2.384527e-04
# [L-BFGS] Iter 39 | Loss: 2.385603e-04
# [L-BFGS] Iter 40 | Loss: 2.472066e-04
# [L-BFGS] Iter 41 | Loss: 2.314388e-04
# [L-BFGS] Iter 42 | Loss: 2.623597e-04
# [L-BFGS] Iter 43 | Loss: 2.427557e-04
# [L-BFGS] Iter 44 | Loss: 2.366086e-04
# [L-BFGS] Iter 45 | Loss: 2.318760e-04
# [L-BFGS] Iter 46 | Loss: 2.723256e-04
# [L-BFGS] Iter 47 | Loss: 2.417671e-04
# [L-BFGS] Iter 48 | Loss: 2.328984e-04
# [L-BFGS] Iter 49 | Loss: 2.474625e-04
# [L-BFGS] Iter 50 | Loss: 2.441319e-04
# [L-BFGS] Iter 51 | Loss: 2.420001e-04
# [L-BFGS] Iter 52 | Loss: 2.384927e-04
# [L-BFGS] Iter 53 | Loss: 2.478570e-04
# [L-BFGS] Iter 54 | Loss: 2.312702e-04
# [L-BFGS] Iter 55 | Loss: 2.799213e-04
# [L-BFGS] Iter 56 | Loss: 2.341448e-04
# [L-BFGS] Iter 57 | Loss: 2.264607e-04
# [L-BFGS] Iter 58 | Loss: 2.306310e-04
# [L-BFGS] Iter 59 | Loss: 2.635558e-04
# [L-BFGS] Iter 60 | Loss: 2.367223e-04
# [L-BFGS] Iter 61 | Loss: 2.463590e-04
# [L-BFGS] Iter 62 | Loss: 2.272961e-04
# [L-BFGS] Iter 63 | Loss: 2.731073e-04
# [L-BFGS] Iter 64 | Loss: 2.751100e-04
# [L-BFGS] Iter 65 | Loss: 2.395585e-04
# [L-BFGS] Iter 66 | Loss: 2.276758e-04
# [L-BFGS] Iter 67 | Loss: 2.568027e-04
# [L-BFGS] Iter 68 | Loss: 2.500383e-04
# [L-BFGS] Iter 69 | Loss: 2.270605e-04
# [L-BFGS] Iter 70 | Loss: 2.668407e-04
# [L-BFGS] Iter 71 | Loss: 2.695297e-04
# [L-BFGS] Iter 72 | Loss: 2.257091e-04
# [L-BFGS] Iter 73 | Loss: 2.309124e-04
# [L-BFGS] Iter 74 | Loss: 2.280360e-04
# [L-BFGS] Iter 75 | Loss: 2.254243e-04
# [L-BFGS] Iter 76 | Loss: 2.525629e-04
# [L-BFGS] Iter 77 | Loss: 2.581883e-04
# [L-BFGS] Iter 78 | Loss: 2.294173e-04
# [L-BFGS] Iter 79 | Loss: 2.396379e-04
# [L-BFGS] Iter 80 | Loss: 2.276612e-04
# [L-BFGS] Iter 81 | Loss: 2.545781e-04
# [L-BFGS] Iter 82 | Loss: 2.580399e-04
# [L-BFGS] Iter 83 | Loss: 2.505180e-04
# [L-BFGS] Iter 84 | Loss: 2.373195e-04
# [L-BFGS] Iter 85 | Loss: 2.348121e-04
# [L-BFGS] Iter 86 | Loss: 2.359604e-04
# [L-BFGS] Iter 87 | Loss: 2.363804e-04
# [L-BFGS] Iter 88 | Loss: 2.661821e-04
# [L-BFGS] Iter 89 | Loss: 2.163439e-04
# [L-BFGS] Iter 90 | Loss: 2.258820e-04
# [L-BFGS] Iter 91 | Loss: 2.375422e-04
# [L-BFGS] Iter 92 | Loss: 2.436248e-04
# [L-BFGS] Iter 93 | Loss: 2.339979e-04
# [L-BFGS] Iter 94 | Loss: 2.356628e-04
# [L-BFGS] Iter 95 | Loss: 2.234182e-04
# [L-BFGS] Iter 96 | Loss: 2.262089e-04
# [L-BFGS] Iter 97 | Loss: 2.310746e-04
# [L-BFGS] Iter 98 | Loss: 2.627195e-04
# [L-BFGS] Iter 99 | Loss: 2.256729e-04
# [L-BFGS] Iter 100 | Loss: 2.345756e-04
# [L-BFGS] Iter 101 | Loss: 2.338414e-04
# [L-BFGS] Iter 102 | Loss: 2.820644e-04
# [L-BFGS] Iter 103 | Loss: 2.592768e-04
# [L-BFGS] Iter 104 | Loss: 2.301073e-04
# [L-BFGS] Iter 105 | Loss: 2.465364e-04
# [L-BFGS] Iter 106 | Loss: 2.228074e-04
# [L-BFGS] Iter 107 | Loss: 2.275467e-04
# [L-BFGS] Iter 108 | Loss: 2.312966e-04
# [L-BFGS] Iter 109 | Loss: 2.244799e-04
# [L-BFGS] Iter 110 | Loss: 2.522187e-04
# [L-BFGS] Iter 111 | Loss: 2.514938e-04
# [L-BFGS] Iter 112 | Loss: 2.629521e-04
# [L-BFGS] Iter 113 | Loss: 2.275867e-04
# [L-BFGS] Iter 114 | Loss: 2.509531e-04
# [L-BFGS] Iter 115 | Loss: 2.648803e-04
# [L-BFGS] Iter 116 | Loss: 2.293048e-04
# [L-BFGS] Iter 117 | Loss: 2.442987e-04
# [L-BFGS] Iter 118 | Loss: 2.271981e-04
# [L-BFGS] Iter 119 | Loss: 2.139121e-04
# [L-BFGS] Iter 120 | Loss: 2.171773e-04
# [L-BFGS] Iter 121 | Loss: 2.346592e-04
# [L-BFGS] Iter 122 | Loss: 2.259590e-04
# [L-BFGS] Iter 123 | Loss: 2.660600e-04
# [L-BFGS] Iter 124 | Loss: 2.406957e-04
# [L-BFGS] Iter 125 | Loss: 2.274078e-04
# [L-BFGS] Iter 126 | Loss: 2.765386e-04
# [L-BFGS] Iter 127 | Loss: 2.187458e-04
# [L-BFGS] Iter 128 | Loss: 2.116617e-04
# [L-BFGS] Iter 129 | Loss: 2.327073e-04
# [L-BFGS] Iter 130 | Loss: 2.269735e-04
# [L-BFGS] Iter 131 | Loss: 2.154963e-04
# [L-BFGS] Iter 132 | Loss: 2.278840e-04
# [L-BFGS] Iter 133 | Loss: 2.196406e-04
# [L-BFGS] Iter 134 | Loss: 2.082745e-04
# [L-BFGS] Iter 135 | Loss: 2.125944e-04
# [L-BFGS] Iter 136 | Loss: 2.135540e-04
# [L-BFGS] Iter 137 | Loss: 2.283549e-04
# [L-BFGS] Iter 138 | Loss: 2.107893e-04
# [L-BFGS] Iter 139 | Loss: 2.143328e-04
# [L-BFGS] Iter 140 | Loss: 2.355700e-04
# [L-BFGS] Iter 141 | Loss: 2.287055e-04
# [L-BFGS] Iter 142 | Loss: 2.292100e-04
# [L-BFGS] Iter 143 | Loss: 2.355907e-04
# [L-BFGS] Iter 144 | Loss: 2.450512e-04
# [L-BFGS] Iter 145 | Loss: 2.625843e-04
# [L-BFGS] Iter 146 | Loss: 2.124831e-04
# [L-BFGS] Iter 147 | Loss: 2.095537e-04
# [L-BFGS] Iter 148 | Loss: 2.091462e-04
# [L-BFGS] Iter 149 | Loss: 2.311303e-04
# [L-BFGS] Iter 150 | Loss: 2.268430e-04
# [L-BFGS] Iter 151 | Loss: 2.267585e-04
# [L-BFGS] Iter 152 | Loss: 2.299785e-04
# [L-BFGS] Iter 153 | Loss: 2.240342e-04
# [L-BFGS] Iter 154 | Loss: 2.162876e-04
# [L-BFGS] Iter 155 | Loss: 2.281146e-04
# [L-BFGS] Iter 156 | Loss: 2.162763e-04
# [L-BFGS] Iter 157 | Loss: 2.409403e-04
# [L-BFGS] Iter 158 | Loss: 2.497422e-04
# [L-BFGS] Iter 159 | Loss: 2.166992e-04
# [L-BFGS] Iter 160 | Loss: 2.245246e-04
# [L-BFGS] Iter 161 | Loss: 2.276020e-04
# [L-BFGS] Iter 162 | Loss: 2.569430e-04
# [L-BFGS] Iter 163 | Loss: 2.227545e-04
# [L-BFGS] Iter 164 | Loss: 2.340074e-04
# [L-BFGS] Iter 165 | Loss: 2.198119e-04
# [L-BFGS] Iter 166 | Loss: 2.148070e-04
# [L-BFGS] Iter 167 | Loss: 2.162639e-04
# [L-BFGS] Iter 168 | Loss: 2.139328e-04
# [L-BFGS] Iter 169 | Loss: 2.175767e-04
# [L-BFGS] Iter 170 | Loss: 2.504466e-04
# [L-BFGS] Iter 171 | Loss: 2.643385e-04
# [L-BFGS] Iter 172 | Loss: 2.546206e-04
# [L-BFGS] Iter 173 | Loss: 2.201314e-04
# [L-BFGS] Iter 174 | Loss: 2.402569e-04
# [L-BFGS] Iter 175 | Loss: 2.117006e-04
# [L-BFGS] Iter 176 | Loss: 2.175818e-04
# [L-BFGS] Iter 177 | Loss: 2.171336e-04
# [L-BFGS] Iter 178 | Loss: 2.305959e-04
# [L-BFGS] Iter 179 | Loss: 2.322858e-04
# [L-BFGS] Iter 180 | Loss: 2.088270e-04
# [L-BFGS] Iter 181 | Loss: 2.062934e-04
# [L-BFGS] Iter 182 | Loss: 2.096044e-04
# [L-BFGS] Iter 183 | Loss: 2.072337e-04
# [L-BFGS] Iter 184 | Loss: 2.494837e-04
# [L-BFGS] Iter 185 | Loss: 2.162144e-04
# [L-BFGS] Iter 186 | Loss: 2.179769e-04
# [L-BFGS] Iter 187 | Loss: 2.060874e-04
# [L-BFGS] Iter 188 | Loss: 2.030375e-04
# [L-BFGS] Iter 189 | Loss: 2.163980e-04
# [L-BFGS] Iter 190 | Loss: 2.243204e-04
# [L-BFGS] Iter 191 | Loss: 2.536170e-04
# [L-BFGS] Iter 192 | Loss: 2.074190e-04
# [L-BFGS] Iter 193 | Loss: 2.069260e-04
# [L-BFGS] Iter 194 | Loss: 2.524676e-04
# [L-BFGS] Iter 195 | Loss: 2.020699e-04
# [L-BFGS] Iter 196 | Loss: 2.121793e-04
# [L-BFGS] Iter 197 | Loss: 1.953446e-04
# [L-BFGS] Iter 198 | Loss: 1.948873e-04
# [L-BFGS] Iter 199 | Loss: 2.315377e-04
# [L-BFGS] Iter 200 | Loss: 1.897700e-04
# [L-BFGS] Iter 201 | Loss: 2.106415e-04
# [L-BFGS] Iter 202 | Loss: 1.930521e-04
# [L-BFGS] Iter 203 | Loss: 1.968430e-04
# [L-BFGS] Iter 204 | Loss: 2.039352e-04
# [L-BFGS] Iter 205 | Loss: 1.983109e-04
# [L-BFGS] Iter 206 | Loss: 2.208033e-04
# [L-BFGS] Iter 207 | Loss: 2.151656e-04
# [L-BFGS] Iter 208 | Loss: 1.960453e-04
# [L-BFGS] Iter 209 | Loss: 2.337021e-04
# [L-BFGS] Iter 210 | Loss: 1.965666e-04
# [L-BFGS] Iter 211 | Loss: 2.167178e-04
# [L-BFGS] Iter 212 | Loss: 2.102980e-04
# [L-BFGS] Iter 213 | Loss: 2.478583e-04
# [L-BFGS] Iter 214 | Loss: 1.850973e-04
# [L-BFGS] Iter 215 | Loss: 2.515102e-04
# [L-BFGS] Iter 216 | Loss: 1.898042e-04
# [L-BFGS] Iter 217 | Loss: 1.896637e-04
# [L-BFGS] Iter 218 | Loss: 1.996326e-04
# [L-BFGS] Iter 219 | Loss: 1.871392e-04
# [L-BFGS] Iter 220 | Loss: 1.851719e-04
# [L-BFGS] Iter 221 | Loss: 1.934867e-04
# [L-BFGS] Iter 222 | Loss: 1.965000e-04
# [L-BFGS] Iter 223 | Loss: 2.066172e-04
# [L-BFGS] Iter 224 | Loss: 2.392189e-04
# [L-BFGS] Iter 225 | Loss: 1.954743e-04
# [L-BFGS] Iter 226 | Loss: 2.138578e-04
# [L-BFGS] Iter 227 | Loss: 1.995082e-04
# [L-BFGS] Iter 228 | Loss: 1.996728e-04
# [L-BFGS] Iter 229 | Loss: 2.079500e-04
# [L-BFGS] Iter 230 | Loss: 1.919976e-04
# [L-BFGS] Iter 231 | Loss: 1.858873e-04
# [L-BFGS] Iter 232 | Loss: 2.010851e-04
# [L-BFGS] Iter 233 | Loss: 2.127526e-04
# [L-BFGS] Iter 234 | Loss: 1.998070e-04
# [L-BFGS] Iter 235 | Loss: 2.088240e-04
# [L-BFGS] Iter 236 | Loss: 2.147779e-04
# [L-BFGS] Iter 237 | Loss: 2.053184e-04
# [L-BFGS] Iter 238 | Loss: 1.864290e-04
# [L-BFGS] Iter 239 | Loss: 1.881508e-04
# [L-BFGS] Iter 240 | Loss: 1.876955e-04
# [L-BFGS] Iter 241 | Loss: 1.843396e-04
# [L-BFGS] Iter 242 | Loss: 1.989317e-04
# [L-BFGS] Iter 243 | Loss: 1.859910e-04
# [L-BFGS] Iter 244 | Loss: 2.222122e-04
# [L-BFGS] Iter 245 | Loss: 1.850118e-04
# [L-BFGS] Iter 246 | Loss: 1.805189e-04
# [L-BFGS] Iter 247 | Loss: 1.959505e-04
# [L-BFGS] Iter 248 | Loss: 1.831480e-04
# [L-BFGS] Iter 249 | Loss: 1.888765e-04
# [L-BFGS] Iter 250 | Loss: 1.791112e-04
# [L-BFGS] Iter 251 | Loss: 1.610267e-04
# [L-BFGS] Iter 252 | Loss: 1.685398e-04
# [L-BFGS] Iter 253 | Loss: 2.205095e-04
# [L-BFGS] Iter 254 | Loss: 1.857700e-04
# [L-BFGS] Iter 255 | Loss: 2.039167e-04
# [L-BFGS] Iter 256 | Loss: 1.769090e-04
# [L-BFGS] Iter 257 | Loss: 1.786402e-04
# [L-BFGS] Iter 258 | Loss: 2.313144e-04
# [L-BFGS] Iter 259 | Loss: 1.779773e-04
# [L-BFGS] Iter 260 | Loss: 2.004131e-04
# [L-BFGS] Iter 261 | Loss: 1.715644e-04
# [L-BFGS] Iter 262 | Loss: 1.717279e-04
# [L-BFGS] Iter 263 | Loss: 1.963332e-04
# [L-BFGS] Iter 264 | Loss: 1.699401e-04
# [L-BFGS] Iter 265 | Loss: 1.906109e-04
# [L-BFGS] Iter 266 | Loss: 1.975342e-04
# [L-BFGS] Iter 267 | Loss: 1.678578e-04
# [L-BFGS] Iter 268 | Loss: 2.148249e-04
# [L-BFGS] Iter 269 | Loss: 1.675292e-04
# [L-BFGS] Iter 270 | Loss: 2.221649e-04
# [L-BFGS] Iter 271 | Loss: 1.948013e-04
# [L-BFGS] Iter 272 | Loss: 1.859027e-04
# [L-BFGS] Iter 273 | Loss: 1.708671e-04
# [L-BFGS] Iter 274 | Loss: 2.355905e-04
# [L-BFGS] Iter 275 | Loss: 2.072052e-04
# [L-BFGS] Iter 276 | Loss: 1.694218e-04
# [L-BFGS] Iter 277 | Loss: 1.657635e-04
# [L-BFGS] Iter 278 | Loss: 1.775983e-04
# [L-BFGS] Iter 279 | Loss: 1.636395e-04
# [L-BFGS] Iter 280 | Loss: 1.674277e-04
# [L-BFGS] Iter 281 | Loss: 1.742381e-04
# [L-BFGS] Iter 282 | Loss: 1.658276e-04
# [L-BFGS] Iter 283 | Loss: 1.734614e-04
# [L-BFGS] Iter 284 | Loss: 1.828595e-04
# [L-BFGS] Iter 285 | Loss: 1.686057e-04
# [L-BFGS] Iter 286 | Loss: 1.860227e-04
# [L-BFGS] Iter 287 | Loss: 1.761510e-04
# [L-BFGS] Iter 288 | Loss: 2.161004e-04
# [L-BFGS] Iter 289 | Loss: 1.737173e-04
# [L-BFGS] Iter 290 | Loss: 2.117659e-04
# [L-BFGS] Iter 291 | Loss: 2.069815e-04
# [L-BFGS] Iter 292 | Loss: 1.726038e-04
# [L-BFGS] Iter 293 | Loss: 1.855243e-04
# [L-BFGS] Iter 294 | Loss: 1.791980e-04
# [L-BFGS] Iter 295 | Loss: 1.947507e-04
# [L-BFGS] Iter 296 | Loss: 2.037082e-04
# [L-BFGS] Iter 297 | Loss: 1.613967e-04
# [L-BFGS] Iter 298 | Loss: 1.978623e-04
# [L-BFGS] Iter 299 | Loss: 1.978351e-04
# [L-BFGS] Iter 300 | Loss: 1.633013e-04

# %%
data_ = torch.tensor(XU_grid, dtype=torch.float64)

u_pred = pibi.predict_u_inside(data_[:,0:2])
u_pibi = u_pred.reshape(X_grid.shape)

plt.figure(figsize=(5, 5))
plt.imshow(u_pibi.detach(), cmap='magma', extent=(-1, 1, -1, 1))
plt.colorbar()
plt.show()

# %%
u_analitic = XU_grid[:,-1].reshape(X_grid.shape)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(np.abs(u_pibi.detach()-u_analitic))
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_1303932/3689449685.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   plt.imshow(np.abs(u_pibi.detach()-u_analitic))
