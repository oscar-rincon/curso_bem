# %%
# load packages
import torch
import torch.nn as nn
import numpy as np
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.font_manager import FontProperties
import os
from datetime import datetime
from sklearn.datasets import make_spd_matrix
from torch.utils.data import random_split, DataLoader
from scipy.stats import qmc
import time

# %%
def u_analytic(x, y):
    return np.sin(x) * np.sinh(y)

# %%
def integration_points(n_int):
    points = torch.linspace(0, 4, n_int+1)[:-1]
    points += torch.rand(points.shape) * (1 / n_int) + np.random.rand() * 0.05 # random shift

    # points on square
    epsilon =  0.3 # changeable: set the boundary an espilon away from the Omega boundary
    side = 2 + 2*epsilon
    middle = torch.tensor((0,0)).view(1,2)
    points = torch.remainder(points, 4) # transform points to [0,4]
    v1 = torch.tensor((0, side))[None,]
    v2 = torch.tensor((side, 0))[None,]
    v3 = torch.tensor((0, -side))[None,]
    v4 = torch.tensor((-side, 0))[None,]
    points = points.view(-1,1)
    x_int = (middle - 0.5 * (v1 + v2) + torch.clamp(points,0,1) * v1 + torch.clamp(points-1,0,1) * v2 + torch.clamp(points-2,0,1) * v3 + torch.clamp(points-3,0,1) * v4).requires_grad_(True)

    return x_int

# %%
# outer normal directional derivative on boundary of Omega (as a circle)
def outer_normal(x):

    middle = torch.tensor((0,0)).view(1,2)
    max_indices = torch.argmax(torch.abs(x - middle), dim=-1, keepdim=False)
    normals = torch.zeros_like(x)
    sign = torch.sign(x)
    temp_range = torch.arange(x.size(0))
    normals[temp_range, max_indices] = sign[temp_range, max_indices]

    return normals

# %%
# fundamental solution of Laplace equation in 2D
def fundamental_solution(x, y, L=None):
    diff = x - y
    if L is None:
        L = torch.tensor(4 * 2 / y.shape[0], dtype=x.dtype, device=x.device)

    Phi_analytic = -L / (2 * torch.pi) * (torch.log(L / 2) - 1)    
    distance = torch.norm(x - y, p=2, dim=1).view(-1,1)
    Phi_0 = -1/(2*torch.pi) * torch.log(distance)

    return Phi_0


# gradient of fundamental solution with respect to y
# grad Phi_0(x,y) = 1/(2π) * (x - y)/||x - y||²
def gradient_fundamental(x, y):
    diff = x - y
    distance = torch.norm(x - y, p=2, dim=1).view(-1,1)
    grad_analytic = torch.full_like(diff, -0.5)
    grad_Phi_0 = (1/(2*torch.pi)) * ((x - y) / distance**2)
    
    return grad_Phi_0

# %%
# fully-connected neural network setup with PyTorch
class FCNN(nn.Module):
    def __init__(self, N_input, N_output, N_hidden, N_layers, n_int):

        super().__init__()
        activation = nn.Tanh
        self.n_int = n_int

        # input / start layer
        self.fc_start = nn.Sequential(*[
                                nn.Linear(N_input, N_hidden),
                                activation()
                                ])
        # hidden layers
        self.fc_hidden = nn.Sequential(*[
                                nn.Sequential(*[
                                    nn.Linear(N_hidden, N_hidden),
                                    activation()
                                    ])
                                for _ in range(N_layers-1) # -1 since first layer already defined before for-loop
                                ])
        # output / end layer
        self.fc_end = nn.Linear(N_hidden, N_output)

    #------------------------------
    # forward pass through network
    def forward(self, x):
        # map x to [-1,1]
        epsilon =  0.3
        x_scaled = 2*(x - torch.tensor([-1-epsilon, -1-epsilon]))/(torch.tensor([1+epsilon, 1+epsilon]) - torch.tensor([-1-epsilon, -1-epsilon])) - 1
        #x_scaled = 2*(x - torch.tensor([x_min, y_min]))/(torch.tensor([x_max, y_max]) - torch.tensor([x_min, y_min])) - 1
        # forward pass
        x_scaled = self.fc_start(x_scaled)  # input layer
        x_scaled = self.fc_hidden(x_scaled) # hidden layer(s)
        u = self.fc_end(x_scaled)    # output layer
        return u

    #------------------------------
    # calculating the potential integrals
    def resample(self):
        # sampling new collocation and integration points
        self.x_int = integration_points(self.n_int)
        # calculating the potential
        self.vmapped_potential_inside = torch.vmap(self.calc_potentials_inside, randomness='same')

    #------------------------------
    # calculating the single and double layer potentials for x being an inside Omega point
    def calc_potentials_inside(self, x):

        epsilon =  0.3
        side = 2 + 2*epsilon

        y = self.x_int
        normal_y = outer_normal(y)
        h_y = self(y) # boundary density, performs forward pass through  neural network with the input y

 

        G =  fundamental_solution(x, y)
         
        grad_ones = torch.ones_like(h_y)
        dh_dy = torch.autograd.grad(h_y, y, grad_outputs=grad_ones, create_graph=True)[0]
        dh_dn = torch.sum(dh_dy * normal_y, dim=1).view(-1, 1)
        single_layer = 4*side*torch.mean(G * dh_dn)
        ################
        # double_layer
        dG_dy =  gradient_fundamental(x, y)
        dG_dn = torch.sum(dG_dy * normal_y, dim=1).view(-1, 1)
        double_layer = 4*side*torch.mean(dG_dn * h_y)


        return single_layer.squeeze(), double_layer.squeeze()

    #------------------------------
    def predict_u_inside(self, x):
        y = self.x_int
        single_layer, double_layer = self.vmapped_potential_inside(x)
        u_int_data = (single_layer.squeeze() - double_layer.squeeze()).view(-1, 1)

        return u_int_data

# %%
def initialise_pibi(lr, n_int):

    # define number of neurons in each layer type
    N_input  = 2
    N_output = 1
    N_hidden = 100 # changeable, use 2**n for efficient memory usage and computation
    N_layers = 3 # number of hidden layers

    # define a neural network to train
    pibi = FCNN(N_input, N_output, N_hidden, N_layers, n_int)
    
    # optimizer
    optimiser = torch.optim.Adam(pibi.parameters(), lr=lr)

    # loss function
    mse_loss = torch.nn.MSELoss() # Mean squared error
    
    return pibi, optimiser, mse_loss

# %%
# Número de muestras a generar (para malla regular y para LHS)
n_samples = 300 # number of samples
n_int = 300 # number of integration points

# Crear malla regular en el dominio [0,1]x[0,1]
x = np.linspace(-1, 1, n_samples)
y = np.linspace(-1, 1, n_samples)
X_grid, Y_grid = np.meshgrid(x, y)

# Evaluar solución analítica sobre la malla regular
U_grid = u_analytic(X_grid, Y_grid)

# Aplanar y combinar en una matriz (x, y, u) para la malla regular
num_points = n_samples ** 2
XU_grid = np.column_stack((
    X_grid.reshape(num_points),
    Y_grid.reshape(num_points),
    U_grid.reshape(num_points)
))

# Generar muestras usando Latin Hypercube Sampling (LHS)
lhs_sampler = qmc.LatinHypercube(d=2)
lhs_samples = lhs_sampler.random(n=n_samples)

# Escalar las muestras al dominio [0,1]x[0,1]
domain_bounds_lower = [-1, -1]
domain_bounds_upper = [1, 1]
lhs_scaled = qmc.scale(lhs_samples, domain_bounds_lower, domain_bounds_upper)

# Evaluar solución analítica en las muestras LHS
X_lhs, Y_lhs = lhs_scaled[:, 0], lhs_scaled[:, 1]
U_lhs = u_analytic(X_lhs, Y_lhs)

# Combinar en una matriz (x, y, u) para las muestras LHS
XU_lhs_interior = np.column_stack((X_lhs, Y_lhs, U_lhs))

# generar puntos de integración
x_int = integration_points(n_int)

# %%
# Supón que u_analytic está definida y n_samples también
# u_analytic = lambda x, y: alguna expresión analítica
n_samples = 200  # por ejemplo

# Número total de muestras en la frontera
n_side = n_samples // 4
lhs_1d = qmc.LatinHypercube(d=1).random(n=n_side)
lhs_1d = 2 * lhs_1d - 1  # escalar a [-1, 1]

# Lados del cuadrado
bottom = np.column_stack((lhs_1d[:, 0], -np.ones(n_side)))
top    = np.column_stack((lhs_1d[:, 0],  np.ones(n_side)))
left   = np.column_stack((-np.ones(n_side), lhs_1d[:, 0]))
right  = np.column_stack(( np.ones(n_side), lhs_1d[:, 0]))

# Unir todos los puntos de frontera
boundary_points = np.vstack((bottom, top, left, right))

# Evaluar la solución analítica
X_lhs, Y_lhs = boundary_points[:, 0], boundary_points[:, 1]
U_lhs = u_analytic(X_lhs, Y_lhs)

# Graficar con color de acuerdo a u
plt.figure(figsize=(4, 4))
sc = plt.scatter(X_lhs, Y_lhs, c=U_lhs, cmap='magma', s=20)
plt.colorbar(sc, label='$u(x, y)$',shrink=0.7)  # barra de colores
plt.xlim([-1.1, 1.1])
plt.ylim([-1.1, 1.1])
plt.gca().set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
#plt.title('Puntos de evaluación')
#plt.grid(True)
# Guardar la figura
plt.savefig('boundary_points.svg')
plt.show()

# %%
data_ = torch.tensor(XU_grid, dtype=torch.float64)
plt.figure(figsize=(4, 4))
plt.imshow(U_grid, extent=(-1, 1, -1, 1), origin='lower', cmap="magma")
plt.title('Solución analítica')
plt.colorbar(shrink=0.8, label='$u(x, y)$')
plt.savefig('solucion_analitica.svg')
plt.show()

# %%
# plot outer normal and x_int
figure, ax = plt.subplots(figsize=(4, 4))
plt.scatter(x_int[:, 0].detach().numpy(), x_int[:, 1].detach().numpy())
plt.scatter(x_int[5, 0].detach().numpy(), x_int[5, 1].detach().numpy())
plt.show()
#plt.quiver(x_int[:, 0].detach().numpy(), x_int[:, 1].detach().numpy(), outer_normal(x_int)[:, 0].detach().numpy(), outer_normal(x_int)[:, 1].detach().numpy())

# %%
def train_pibi(iterations, pibi, optimiser, mse_loss, data, data_n, n_samples, n_int, time_now, show_plots):

    # store loss values
    loss_values = []
 
    for epoch in range(iterations):

        # Clear gradients before forward and backward pass for each batch to avoid accumulation of gradients
        optimiser.zero_grad()

        # compute data loss
        pibi.resample()
        u_int_data = pibi.predict_u_inside(data[:,0:2])
        #source_data = torch.zeros_like(u_int_data)
        source_data = (32*((1 - data[:,1])*data[:,1] + (1 - data[:,0])*data[:,0]))* fundamental_solution(data[:,0:2], torch.ones_like(data[:,0:2])).view(-1,1)
        u_int_data = u_int_data +  source_data
        loss = mse_loss(u_int_data, data[:,-1].view(-1,1))
        loss_values.append(loss.item())

        # backpropagate loss, take optimiser step
        loss.backward()
        optimiser.step()
        print('Epoch:', epoch, 'Loss:', loss.item())

    return pibi, loss_values

# %%
show_plots = True

# take samples
time_now = datetime.now().strftime("%Y%m%d_%H%M")
data = torch.tensor(XU_lhs, dtype=torch.float64)
data_ = torch.tensor(XU_grid, dtype=torch.float64)

# # pibi initialisation
lr = 0.001 # learning rate
pibi, optimiser, mse_loss = initialise_pibi(lr, n_int)
    
# # train pibi-net
# iterations = 1_001
# pibi, loss_values = train_pibi(iterations, pibi, optimiser, mse_loss, data, 00, n_samples, n_int, time_now, show_plots)

# %%
def train_pibi_lbfgs(pibi, mse_loss, data, max_iter=100):
    print("\nStarting L-BFGS refinement...")

    def closure():
        optimizer_lbfgs.zero_grad()
        pibi.resample()  # en caso de que resamplee los puntos en cada forward
        u_int_data = pibi.predict_u_inside(data[:, :2])
        loss = mse_loss(u_int_data, data[:, -1].view(-1, 1))
        loss.backward()
        return loss

    optimizer_lbfgs = torch.optim.LBFGS(
        pibi.parameters(),
        lr=1,
        max_iter=max_iter,
        history_size=100,
        line_search_fn="strong_wolfe",
        tolerance_grad=1e-7,
        tolerance_change=1.0 * np.finfo(float).eps
    )

    loss_values_lbfgs = []

    for i in range(max_iter):
        loss = optimizer_lbfgs.step(closure)
        loss_values_lbfgs.append(loss.item())
        print(f"[L-BFGS] Iter {i} | Loss: {loss.item():.6e}")

    return pibi, loss_values_lbfgs

# %%
from datetime import datetime

show_plots = True
time_now = datetime.now().strftime("%Y%m%d_%H%M")

# Cargar datos
data = torch.tensor(XU_lhs, dtype=torch.float64)

# Inicialización de PIBI
lr = 0.001
#pibi, optimiser, mse_loss = initialise_pibi(lr, n_int)

# Primera fase: optimizador tipo Adam
iterations = 301
#pibi, loss_values_adam = train_pibi(iterations, pibi, optimiser, mse_loss, data, 00, n_samples, n_int, time_now, show_plots)

# Segunda fase: refinamiento con L-BFGS
pibi, loss_values_lbfgs = train_pibi_lbfgs(pibi, mse_loss, data, max_iter=iterations)
# Out:
# Starting L-BFGS refinement...
# [L-BFGS] Iter 0 | Loss: 3.379960e-01
# [L-BFGS] Iter 1 | Loss: 3.384672e-03
# [L-BFGS] Iter 2 | Loss: 3.447785e-03
# [L-BFGS] Iter 3 | Loss: 3.535605e-03
# [L-BFGS] Iter 4 | Loss: 3.122228e-03
# [L-BFGS] Iter 5 | Loss: 3.472319e-03
# [L-BFGS] Iter 6 | Loss: 3.388835e-03
# [L-BFGS] Iter 7 | Loss: 3.188524e-03
# [L-BFGS] Iter 8 | Loss: 3.232443e-03
# [L-BFGS] Iter 9 | Loss: 3.215254e-03
# [L-BFGS] Iter 10 | Loss: 3.207665e-03
# [L-BFGS] Iter 11 | Loss: 3.274998e-03
# [L-BFGS] Iter 12 | Loss: 3.040627e-03
# [L-BFGS] Iter 13 | Loss: 3.079542e-03
# [L-BFGS] Iter 14 | Loss: 2.897044e-03
# [L-BFGS] Iter 15 | Loss: 3.055463e-03
# [L-BFGS] Iter 16 | Loss: 1.553107e-03
# [L-BFGS] Iter 17 | Loss: 1.582240e-03
# [L-BFGS] Iter 18 | Loss: 1.546268e-03
# [L-BFGS] Iter 19 | Loss: 1.585701e-03
# [L-BFGS] Iter 20 | Loss: 1.538934e-03
# [L-BFGS] Iter 21 | Loss: 1.561902e-03
# [L-BFGS] Iter 22 | Loss: 1.403100e-03
# [L-BFGS] Iter 23 | Loss: 1.312659e-03
# [L-BFGS] Iter 24 | Loss: 1.265094e-03
# [L-BFGS] Iter 25 | Loss: 1.264738e-03
# [L-BFGS] Iter 26 | Loss: 1.223124e-03
# [L-BFGS] Iter 27 | Loss: 1.290566e-03
# [L-BFGS] Iter 28 | Loss: 9.361016e-04
# [L-BFGS] Iter 29 | Loss: 9.026092e-04
# [L-BFGS] Iter 30 | Loss: 8.975888e-04
# [L-BFGS] Iter 31 | Loss: 7.723646e-04
# [L-BFGS] Iter 32 | Loss: 5.590180e-04
# [L-BFGS] Iter 33 | Loss: 6.433123e-04
# [L-BFGS] Iter 34 | Loss: 5.512231e-04
# [L-BFGS] Iter 35 | Loss: 6.454549e-04
# [L-BFGS] Iter 36 | Loss: 6.402044e-04
# [L-BFGS] Iter 37 | Loss: 5.273529e-04
# [L-BFGS] Iter 38 | Loss: 5.230972e-04
# [L-BFGS] Iter 39 | Loss: 5.874152e-04
# [L-BFGS] Iter 40 | Loss: 5.163895e-04
# [L-BFGS] Iter 41 | Loss: 5.517614e-04
# [L-BFGS] Iter 42 | Loss: 6.001702e-04
# [L-BFGS] Iter 43 | Loss: 5.171087e-04
# [L-BFGS] Iter 44 | Loss: 5.501148e-04
# [L-BFGS] Iter 45 | Loss: 5.530060e-04
# [L-BFGS] Iter 46 | Loss: 4.174248e-04
# [L-BFGS] Iter 47 | Loss: 4.023905e-04
# [L-BFGS] Iter 48 | Loss: 3.431740e-04
# [L-BFGS] Iter 49 | Loss: 2.246917e-04
# [L-BFGS] Iter 50 | Loss: 1.857241e-04
# [L-BFGS] Iter 51 | Loss: 1.919775e-04
# [L-BFGS] Iter 52 | Loss: 1.995755e-04
# [L-BFGS] Iter 53 | Loss: 2.196352e-04
# [L-BFGS] Iter 54 | Loss: 1.986467e-04
# [L-BFGS] Iter 55 | Loss: 2.209488e-04
# [L-BFGS] Iter 56 | Loss: 1.844727e-04
# [L-BFGS] Iter 57 | Loss: 2.137223e-04
# [L-BFGS] Iter 58 | Loss: 1.974072e-04
# [L-BFGS] Iter 59 | Loss: 1.961983e-04
# [L-BFGS] Iter 60 | Loss: 1.864993e-04
# [L-BFGS] Iter 61 | Loss: 1.811342e-04
# [L-BFGS] Iter 62 | Loss: 1.744687e-04
# [L-BFGS] Iter 63 | Loss: 2.159855e-04
# [L-BFGS] Iter 64 | Loss: 1.741069e-04
# [L-BFGS] Iter 65 | Loss: 1.815022e-04
# [L-BFGS] Iter 66 | Loss: 1.760877e-04
# [L-BFGS] Iter 67 | Loss: 1.679778e-04
# [L-BFGS] Iter 68 | Loss: 1.654299e-04
# [L-BFGS] Iter 69 | Loss: 1.706307e-04
# [L-BFGS] Iter 70 | Loss: 1.438127e-04
# [L-BFGS] Iter 71 | Loss: 1.870520e-04
# [L-BFGS] Iter 72 | Loss: 1.624417e-04
# [L-BFGS] Iter 73 | Loss: 1.543723e-04
# [L-BFGS] Iter 74 | Loss: 1.440923e-04
# [L-BFGS] Iter 75 | Loss: 1.485715e-04
# [L-BFGS] Iter 76 | Loss: 1.447891e-04
# [L-BFGS] Iter 77 | Loss: 2.132782e-04
# [L-BFGS] Iter 78 | Loss: 1.420776e-04
# [L-BFGS] Iter 79 | Loss: 1.400928e-04
# [L-BFGS] Iter 80 | Loss: 1.428281e-04
# [L-BFGS] Iter 81 | Loss: 1.362124e-04
# [L-BFGS] Iter 82 | Loss: 1.339484e-04
# [L-BFGS] Iter 83 | Loss: 1.356574e-04
# [L-BFGS] Iter 84 | Loss: 1.558683e-04
# [L-BFGS] Iter 85 | Loss: 1.513752e-04
# [L-BFGS] Iter 86 | Loss: 1.368958e-04
# [L-BFGS] Iter 87 | Loss: 1.425541e-04
# [L-BFGS] Iter 88 | Loss: 1.334710e-04
# [L-BFGS] Iter 89 | Loss: 1.452975e-04
# [L-BFGS] Iter 90 | Loss: 1.323827e-04
# [L-BFGS] Iter 91 | Loss: 1.965212e-04
# [L-BFGS] Iter 92 | Loss: 1.626914e-04
# [L-BFGS] Iter 93 | Loss: 1.410272e-04
# [L-BFGS] Iter 94 | Loss: 1.501970e-04
# [L-BFGS] Iter 95 | Loss: 1.346598e-04
# [L-BFGS] Iter 96 | Loss: 1.879035e-04
# [L-BFGS] Iter 97 | Loss: 1.449024e-04
# [L-BFGS] Iter 98 | Loss: 1.267517e-04
# [L-BFGS] Iter 99 | Loss: 1.342406e-04
# [L-BFGS] Iter 100 | Loss: 1.466024e-04
# [L-BFGS] Iter 101 | Loss: 1.532477e-04
# [L-BFGS] Iter 102 | Loss: 1.870774e-04
# [L-BFGS] Iter 103 | Loss: 1.512972e-04
# [L-BFGS] Iter 104 | Loss: 1.355505e-04
# [L-BFGS] Iter 105 | Loss: 1.335634e-04
# [L-BFGS] Iter 106 | Loss: 1.445222e-04
# [L-BFGS] Iter 107 | Loss: 1.711527e-04
# [L-BFGS] Iter 108 | Loss: 1.316847e-04
# [L-BFGS] Iter 109 | Loss: 1.476065e-04
# [L-BFGS] Iter 110 | Loss: 1.585387e-04
# [L-BFGS] Iter 111 | Loss: 1.468813e-04
# [L-BFGS] Iter 112 | Loss: 1.535350e-04
# [L-BFGS] Iter 113 | Loss: 1.279463e-04
# [L-BFGS] Iter 114 | Loss: 1.274351e-04
# [L-BFGS] Iter 115 | Loss: 1.436765e-04
# [L-BFGS] Iter 116 | Loss: 1.333755e-04
# [L-BFGS] Iter 117 | Loss: 1.566103e-04
# [L-BFGS] Iter 118 | Loss: 1.323377e-04
# [L-BFGS] Iter 119 | Loss: 1.333229e-04
# [L-BFGS] Iter 120 | Loss: 1.316088e-04
# [L-BFGS] Iter 121 | Loss: 1.771039e-04
# [L-BFGS] Iter 122 | Loss: 1.458962e-04
# [L-BFGS] Iter 123 | Loss: 1.368664e-04
# [L-BFGS] Iter 124 | Loss: 1.818657e-04
# [L-BFGS] Iter 125 | Loss: 1.311331e-04
# [L-BFGS] Iter 126 | Loss: 1.328723e-04
# [L-BFGS] Iter 127 | Loss: 1.344714e-04
# [L-BFGS] Iter 128 | Loss: 1.694383e-04
# [L-BFGS] Iter 129 | Loss: 1.462738e-04
# [L-BFGS] Iter 130 | Loss: 1.432091e-04
# [L-BFGS] Iter 131 | Loss: 1.622128e-04
# [L-BFGS] Iter 132 | Loss: 1.426912e-04
# [L-BFGS] Iter 133 | Loss: 1.433039e-04
# [L-BFGS] Iter 134 | Loss: 1.443548e-04
# [L-BFGS] Iter 135 | Loss: 2.157712e-04
# [L-BFGS] Iter 136 | Loss: 1.317938e-04
# [L-BFGS] Iter 137 | Loss: 1.629912e-04
# [L-BFGS] Iter 138 | Loss: 1.220954e-04
# [L-BFGS] Iter 139 | Loss: 1.682543e-04
# [L-BFGS] Iter 140 | Loss: 1.796462e-04
# [L-BFGS] Iter 141 | Loss: 1.943178e-04
# [L-BFGS] Iter 142 | Loss: 2.219488e-04
# [L-BFGS] Iter 143 | Loss: 1.288896e-04
# [L-BFGS] Iter 144 | Loss: 1.394645e-04
# [L-BFGS] Iter 145 | Loss: 1.323729e-04
# [L-BFGS] Iter 146 | Loss: 1.230550e-04
# [L-BFGS] Iter 147 | Loss: 1.281853e-04
# [L-BFGS] Iter 148 | Loss: 1.305463e-04
# [L-BFGS] Iter 149 | Loss: 1.418992e-04
# [L-BFGS] Iter 150 | Loss: 1.340878e-04
# [L-BFGS] Iter 151 | Loss: 1.839444e-04
# [L-BFGS] Iter 152 | Loss: 1.258512e-04
# [L-BFGS] Iter 153 | Loss: 1.405312e-04
# [L-BFGS] Iter 154 | Loss: 1.315446e-04
# [L-BFGS] Iter 155 | Loss: 1.309978e-04
# [L-BFGS] Iter 156 | Loss: 1.853838e-04
# [L-BFGS] Iter 157 | Loss: 1.311350e-04
# [L-BFGS] Iter 158 | Loss: 1.245638e-04
# [L-BFGS] Iter 159 | Loss: 1.522130e-04
# [L-BFGS] Iter 160 | Loss: 1.300653e-04
# [L-BFGS] Iter 161 | Loss: 1.319340e-04
# [L-BFGS] Iter 162 | Loss: 1.261326e-04
# [L-BFGS] Iter 163 | Loss: 1.272013e-04
# [L-BFGS] Iter 164 | Loss: 1.789164e-04
# [L-BFGS] Iter 165 | Loss: 1.477212e-04
# [L-BFGS] Iter 166 | Loss: 1.327612e-04
# [L-BFGS] Iter 167 | Loss: 1.430016e-04
# [L-BFGS] Iter 168 | Loss: 1.255592e-04
# [L-BFGS] Iter 169 | Loss: 1.275080e-04
# [L-BFGS] Iter 170 | Loss: 1.411561e-04
# [L-BFGS] Iter 171 | Loss: 1.237515e-04
# [L-BFGS] Iter 172 | Loss: 1.827610e-04
# [L-BFGS] Iter 173 | Loss: 1.456479e-04
# [L-BFGS] Iter 174 | Loss: 1.772787e-04
# [L-BFGS] Iter 175 | Loss: 1.233626e-04
# [L-BFGS] Iter 176 | Loss: 1.265603e-04
# [L-BFGS] Iter 177 | Loss: 1.525906e-04
# [L-BFGS] Iter 178 | Loss: 1.280442e-04
# [L-BFGS] Iter 179 | Loss: 1.556324e-04
# [L-BFGS] Iter 180 | Loss: 1.258474e-04
# [L-BFGS] Iter 181 | Loss: 1.432232e-04
# [L-BFGS] Iter 182 | Loss: 2.014052e-04
# [L-BFGS] Iter 183 | Loss: 1.446052e-04
# [L-BFGS] Iter 184 | Loss: 1.823511e-04
# [L-BFGS] Iter 185 | Loss: 1.762771e-04
# [L-BFGS] Iter 186 | Loss: 1.269282e-04
# [L-BFGS] Iter 187 | Loss: 1.435974e-04
# [L-BFGS] Iter 188 | Loss: 1.353081e-04
# [L-BFGS] Iter 189 | Loss: 1.357391e-04
# [L-BFGS] Iter 190 | Loss: 1.274233e-04
# [L-BFGS] Iter 191 | Loss: 1.339150e-04
# [L-BFGS] Iter 192 | Loss: 1.272004e-04
# [L-BFGS] Iter 193 | Loss: 1.341993e-04
# [L-BFGS] Iter 194 | Loss: 1.365809e-04
# [L-BFGS] Iter 195 | Loss: 1.282679e-04
# [L-BFGS] Iter 196 | Loss: 1.224008e-04
# [L-BFGS] Iter 197 | Loss: 1.256467e-04
# [L-BFGS] Iter 198 | Loss: 1.829260e-04
# [L-BFGS] Iter 199 | Loss: 1.261484e-04
# [L-BFGS] Iter 200 | Loss: 1.715931e-04
# [L-BFGS] Iter 201 | Loss: 1.713805e-04
# [L-BFGS] Iter 202 | Loss: 1.689357e-04
# [L-BFGS] Iter 203 | Loss: 1.304151e-04
# [L-BFGS] Iter 204 | Loss: 1.262934e-04
# [L-BFGS] Iter 205 | Loss: 1.207589e-04
# [L-BFGS] Iter 206 | Loss: 1.856438e-04
# [L-BFGS] Iter 207 | Loss: 1.338857e-04
# [L-BFGS] Iter 208 | Loss: 1.364354e-04
# [L-BFGS] Iter 209 | Loss: 1.839648e-04
# [L-BFGS] Iter 210 | Loss: 1.398342e-04
# [L-BFGS] Iter 211 | Loss: 1.307702e-04
# [L-BFGS] Iter 212 | Loss: 1.469756e-04
# [L-BFGS] Iter 213 | Loss: 1.388179e-04
# [L-BFGS] Iter 214 | Loss: 1.616241e-04
# [L-BFGS] Iter 215 | Loss: 2.164938e-04
# [L-BFGS] Iter 216 | Loss: 1.389048e-04
# [L-BFGS] Iter 217 | Loss: 1.288970e-04
# [L-BFGS] Iter 218 | Loss: 1.747805e-04
# [L-BFGS] Iter 219 | Loss: 1.551983e-04
# [L-BFGS] Iter 220 | Loss: 1.374904e-04
# [L-BFGS] Iter 221 | Loss: 1.308642e-04
# [L-BFGS] Iter 222 | Loss: 1.394246e-04
# [L-BFGS] Iter 223 | Loss: 1.348754e-04
# [L-BFGS] Iter 224 | Loss: 1.307361e-04
# [L-BFGS] Iter 225 | Loss: 1.232398e-04
# [L-BFGS] Iter 226 | Loss: 1.307744e-04
# [L-BFGS] Iter 227 | Loss: 1.300142e-04
# [L-BFGS] Iter 228 | Loss: 1.235347e-04
# [L-BFGS] Iter 229 | Loss: 1.533835e-04
# [L-BFGS] Iter 230 | Loss: 1.373112e-04
# [L-BFGS] Iter 231 | Loss: 1.409934e-04
# [L-BFGS] Iter 232 | Loss: 1.536290e-04
# [L-BFGS] Iter 233 | Loss: 1.522508e-04
# [L-BFGS] Iter 234 | Loss: 1.218727e-04
# [L-BFGS] Iter 235 | Loss: 1.392226e-04
# [L-BFGS] Iter 236 | Loss: 1.268152e-04
# [L-BFGS] Iter 237 | Loss: 1.745371e-04
# [L-BFGS] Iter 238 | Loss: 1.412998e-04
# [L-BFGS] Iter 239 | Loss: 1.366562e-04
# [L-BFGS] Iter 240 | Loss: 1.951051e-04
# [L-BFGS] Iter 241 | Loss: 1.550137e-04
# [L-BFGS] Iter 242 | Loss: 1.517326e-04
# [L-BFGS] Iter 243 | Loss: 1.893020e-04
# [L-BFGS] Iter 244 | Loss: 1.517091e-04
# [L-BFGS] Iter 245 | Loss: 1.767535e-04
# [L-BFGS] Iter 246 | Loss: 1.229437e-04
# [L-BFGS] Iter 247 | Loss: 1.460399e-04
# [L-BFGS] Iter 248 | Loss: 1.251190e-04
# [L-BFGS] Iter 249 | Loss: 1.243319e-04
# [L-BFGS] Iter 250 | Loss: 1.385370e-04
# [L-BFGS] Iter 251 | Loss: 1.280365e-04
# [L-BFGS] Iter 252 | Loss: 1.471420e-04
# [L-BFGS] Iter 253 | Loss: 1.291447e-04
# [L-BFGS] Iter 254 | Loss: 1.617232e-04
# [L-BFGS] Iter 255 | Loss: 1.349324e-04
# [L-BFGS] Iter 256 | Loss: 1.227201e-04
# [L-BFGS] Iter 257 | Loss: 1.517353e-04
# [L-BFGS] Iter 258 | Loss: 1.630774e-04
# [L-BFGS] Iter 259 | Loss: 1.255976e-04
# [L-BFGS] Iter 260 | Loss: 1.673313e-04
# [L-BFGS] Iter 261 | Loss: 1.336397e-04
# [L-BFGS] Iter 262 | Loss: 1.746013e-04
# [L-BFGS] Iter 263 | Loss: 1.452547e-04
# [L-BFGS] Iter 264 | Loss: 1.181064e-04
# [L-BFGS] Iter 265 | Loss: 1.323343e-04
# [L-BFGS] Iter 266 | Loss: 1.340150e-04
# [L-BFGS] Iter 267 | Loss: 1.265775e-04
# [L-BFGS] Iter 268 | Loss: 1.628327e-04
# [L-BFGS] Iter 269 | Loss: 2.263125e-04
# [L-BFGS] Iter 270 | Loss: 1.413417e-04
# [L-BFGS] Iter 271 | Loss: 1.327080e-04
# [L-BFGS] Iter 272 | Loss: 1.696324e-04
# [L-BFGS] Iter 273 | Loss: 1.317379e-04
# [L-BFGS] Iter 274 | Loss: 1.279954e-04
# [L-BFGS] Iter 275 | Loss: 1.207583e-04
# [L-BFGS] Iter 276 | Loss: 1.242578e-04
# [L-BFGS] Iter 277 | Loss: 1.316417e-04
# [L-BFGS] Iter 278 | Loss: 1.279548e-04
# [L-BFGS] Iter 279 | Loss: 1.183932e-04
# [L-BFGS] Iter 280 | Loss: 1.283435e-04
# [L-BFGS] Iter 281 | Loss: 1.385250e-04
# [L-BFGS] Iter 282 | Loss: 1.708811e-04
# [L-BFGS] Iter 283 | Loss: 2.117519e-04
# [L-BFGS] Iter 284 | Loss: 1.371412e-04
# [L-BFGS] Iter 285 | Loss: 1.481348e-04
# [L-BFGS] Iter 286 | Loss: 1.221641e-04
# [L-BFGS] Iter 287 | Loss: 1.629449e-04
# [L-BFGS] Iter 288 | Loss: 1.320190e-04
# [L-BFGS] Iter 289 | Loss: 1.412819e-04
# [L-BFGS] Iter 290 | Loss: 1.569273e-04
# [L-BFGS] Iter 291 | Loss: 1.246840e-04
# [L-BFGS] Iter 292 | Loss: 1.242116e-04
# [L-BFGS] Iter 293 | Loss: 1.349151e-04
# [L-BFGS] Iter 294 | Loss: 1.704200e-04
# [L-BFGS] Iter 295 | Loss: 1.287119e-04
# [L-BFGS] Iter 296 | Loss: 1.551750e-04
# [L-BFGS] Iter 297 | Loss: 1.782113e-04
# [L-BFGS] Iter 298 | Loss: 1.253447e-04
# [L-BFGS] Iter 299 | Loss: 1.474446e-04
# [L-BFGS] Iter 300 | Loss: 1.921993e-04

# %%
data_ = torch.tensor(XU_grid, dtype=torch.float64)

u_pred = pibi.predict_u_inside(data_[:,0:2])
u_pibi = u_pred.reshape(X_grid.shape)

plt.figure(figsize=(5, 5))
plt.imshow(u_pibi.detach(), cmap='magma', extent=(-1, 1, -1, 1))
plt.colorbar()
plt.show()

# %%
u_analitic = XU_grid[:,-1].reshape(X_grid.shape)

# %%
plt.figure(figsize=(4, 4))
plt.imshow(np.abs(u_pibi.detach()-u_analitic), cmap='magma', extent=(-1, 1, -1, 1))
plt.colorbar(shrink=0.8, label='$|u_{pred} - u_{analytic}|$')
plt.savefig('error_pibi.svg')
plt.show()
# Out:
# /tmp/ipykernel_60345/1003433482.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   plt.imshow(np.abs(u_pibi.detach()-u_analitic), cmap='magma', extent=(-1, 1, -1, 1))

# %%
# Calcular el error relativo entre el potencial numérico y el exacto
relative_error = np.linalg.norm(u_analitic - u_pibi.detach().numpy(), 2)/np.linalg.norm(u_analitic, 2)
relative_error
# Out:
# np.float64(0.01638943307532987)
